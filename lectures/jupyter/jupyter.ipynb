# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_inline import backend_inline
from ipywidgets import interact
backend_inline.set_matplotlib_formats('retina')

# %% [markdown]
# _Connect code and reports with_
# <br>
#
# <img src="https://jupyter.readthedocs.io/en/latest/_static/_images/jupyter.svg" alt="title" style="float: left;">

# %% [markdown]
# [Jupyter](http://jupyter.org/)
#
# - An open source project for interactive data science and computing
# - Allows you to document, edit and run code directly in your browser

# %% [markdown]
# ## The 'classic' jupyter notebook
#
# <img src='https://docs.jupyter.org/en/latest/_images/trynb.png' alt="title" width="50%">
#
# `$ jupyter notebook`

# %% [markdown]
# The jupyter notebook is scheduled to be 'sunsetted', in favor of the more advanced **Jupyter lab** interface.

# %% [markdown]
# ## Jupyter lab
#
# _The next-generation web-based user interface for Project Jupyter._
#
# <img src="https://jupyterlab.readthedocs.io/en/stable/_images/jupyterlab.png" width="50%">
#
# <font size="5">
#
# - Similar to an integrated development environments (IDE).
# - Tab views, Code consoles, Show output in a separate tab, Live rendering of edits _etc._
# - The jupyter lab interface can run Jupyter notebooks in the **main** work area
#
# `$ jupyter lab`

# %% [markdown]
# ### Notebook basics

# %% [markdown]
# - Runs as a local web server
# - Load/save/manage notebooks from the menu
#
# <img src="https://github.com/NBISweden/workshop-reproducible-research/raw/main/pages/images/jupyter_basic_update.png" alt="title" width="600"  style="float:left;padding:5px;">

# %% [markdown]
# The notebook itself is a JSON file

# %%
# !head -20 jupyter.ipynb
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {
#     "slideshow": {
#      "slide_type": "skip"
#     }
#    },
#    "outputs": [],
#    "source": [
#     "import seaborn as sns\n",
#     "import pandas as pd\n",
#     "import matplotlib.pyplot as plt\n",
#     "from matplotlib_inline import backend_inline\n",
#     "from ipywidgets import interact\n",
#     "backend_inline.set_matplotlib_formats('retina')\n"
#    ]
#   },

# %% [markdown]
# Using Jupyter notebooks

# %% [markdown]
# Document your work in Markdown

# %% [markdown]
# # Penguin data analysis
# Here we will investigate the [Penguin dataset](https://github.com/allisonhorst/palmerpenguins).
#
# -----
# The species included in this set are:
#  - _Adelie_
#  - _Chinstrap_
#  - _Gentoo_

# %% [markdown]
# Execute code directly from the browser, with results attached to the code which generated them

# %%
data = sns.load_dataset("penguins")
data.groupby("species").mean(numeric_only=True)
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.791391      18.346358         189.953642  3700.662252
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.504878      14.982114         217.186992  5076.016260

# %% [markdown]
# Generate plots directly in the browser and/or save to file.

# %%
sns.set_context("paper", rc={"axes.labelsize":6})

# %%
ax = sns.pairplot(data, hue="species", height=1, 
                  plot_kws=dict(s=20, linewidth=0.5), 
                  diag_kws=dict(linewidth=0.5))

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Mix and match languages in addition to `python` (_e.g._ `R`, `bash`, `ruby`)

# %%
# %%R
# x <- 1:12
# sample(x, replace = TRUE)
# Out:
#  [1]  5  2  5  4  6 11 12  1  8  3  6  7

# %%
# %%ruby
# puts "Hello World!"
# Out:
# Hello World!

# %%
# %%bash
# uname -v
# Out:
# Darwin Kernel Version 22.4.0: Mon Mar  6 20:59:58 PST 2023; root:xnu-8796.101.5~3/RELEASE_ARM64_T6020

# %% [markdown]
# Create interactive widgets

# %%
from ipywidgets import interact

def f(palette, x, y):
    plt.figure(1, figsize=(3,3))
    ax = sns.scatterplot(data=data, x=x, y=y, hue="species", palette=palette)
    ax.legend(bbox_to_anchor=(1,1))

_ = interact(f, palette=["Set1","Set2","Dark2","Paired"], 
            y=["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"],
            x=["bill_depth_mm", "bill_length_mm", "flipper_length_mm", "body_mass_g"])
# Out:
# interactive(children=(Dropdown(description='palette', options=('Set1', 'Set2', 'Dark2', 'Paired'), value='Set1…

# %% [markdown]
# Sharing notebooks

# %% [markdown]
# - Put the [notebook](https://github.com/NBISweden/workshop-reproducible-research/blob/main/lectures/jupyter/jupyter.ipynb) on GitHub/Bitbucket and it will be rendered there

# %% [markdown]
# - Export to one of many different formats, _e.g._ HTML, PDF, code, slides _etc._

# %% [markdown]
# - Paste a link to any Jupyter [notebook](https://github.com/NBISweden/workshop-reproducible-research/blob/main/tutorials/jupyter/supplementary_material.ipynb) at [nbviewer.jupyter.org](https://nbviewer.jupyter.org) and it will be rendered for you.

# %% [markdown]
# Or generate interactive notebooks using [Binder](https://mybinder.org)
#
# <img src="https://mybinder.org/static/logo.svg" alt="title" style="float: left;">

# %% [markdown]
# For the tutorial:
#
# - `jupyter lab` - will give you the updated and more advanced Jupyter lab interface
# - `jupyter notebook` - will give you the Classic notebook interface

# %% [markdown]
# # Questions?
